# %%
# !pip install textattack
# !pip install ipywidgets
# !pip install boto3 --upgrade
# !pip install scipy==1.10.1

# %%
# hotflip

command = "textattack attack --model lstm-mr --recipe hotflip --num-examples 500 --log-to-csv ./data/attacks/hotflip_data.data"
import os
os.system(command)

# %%
# textfooler

command = "textattack attack --model roberta-base-sst2 --recipe textfooler --num-examples 500 --log-to-csv ./data/attacks/textfooler_data.data"
import os
os.system(command)

# %%
# alzantot
command = "textattack attack --model roberta-base-sst2 --recipe alzantot --num-examples 500 --log-to-csv ./data/attacks/alzantot_data.data"
import os
os.system(command)
# Out:
#   Cell In[10], line 1
#     textattack attack --model roberta-base-sst2 --recipe alzantot --num-examples 500 --log-to-csv data.csv
#                ^
# SyntaxError: invalid syntax
